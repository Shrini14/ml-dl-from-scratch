# %% [markdown]
# # Gradient Descent

# %%
import numpy as np
x=np.array([1,2,3,4,5])
y =np.array([65,70,75,85,90])
n = len(x)
w,b =0,0  #initial weight and bias
loss = []
for i in range(400):
    y_cap = w*x+b   #y_predict


    J = np.sum((y - y_cap)**2)/n   # Loss function
    print(f"{i} iteration is {J:.2f}")
    loss.append(J)

        
    dj_dw = (-2*np.sum((y-y_cap)*x))/n   # partial derivative for loss with respect to w
    dj_db = (-2*np.sum(y-y_cap))/n       # partial derivative for loss with respect to b


    # 0.5 is the learning rate

    w = w - 0.05*(dj_dw)    # updating weight
    b = b - 0.05*(dj_db)    # updating bias
print(np.round(y_cap,2))
print("w:",w)
print("b:",b)
# Out:
# 0 iteration is 6015.00
# 1 iteration is 657.53
# 2 iteration is 462.69
# 3 iteration is 441.44
# 4 iteration is 426.49
# 5 iteration is 412.24
# 6 iteration is 398.47
# 7 iteration is 385.16
# 8 iteration is 372.30
# 9 iteration is 359.87
# 10 iteration is 347.86
# 11 iteration is 336.25
# 12 iteration is 325.02
# 13 iteration is 314.18
# 14 iteration is 303.70
# 15 iteration is 293.56
# 16 iteration is 283.77
# 17 iteration is 274.31
# 18 iteration is 265.16
# 19 iteration is 256.33
# 20 iteration is 247.78
# 21 iteration is 239.53
# 22 iteration is 231.55
# 23 iteration is 223.84
# 24 iteration is 216.38
# 25 iteration is 209.18
# 26 iteration is 202.22
# 27 iteration is 195.49
# 28 iteration is 188.98
# 29 iteration is 182.70
# 30 iteration is 176.62
# 31 iteration is 170.75
# 32 iteration is 165.08
# 33 iteration is 159.60
# 34 iteration is 154.30
# 35 iteration is 149.17
# 36 iteration is 144.22
# 37 iteration is 139.44
# 38 iteration is 134.81
# 39 iteration is 130.34
# 40 iteration is 126.03
# 41 iteration is 121.85
# 42 iteration is 117.82
# 43 iteration is 113.92
# 44 iteration is 110.15
# 45 iteration is 106.51
# 46 iteration is 102.99
# 47 iteration is 99.58
# 48 iteration is 96.30
# 49 iteration is 93.12
# 50 iteration is 90.05
# 51 iteration is 87.08
# 52 iteration is 84.21
# 53 iteration is 81.44
# 54 iteration is 78.76
# 55 iteration is 76.17
# 56 iteration is 73.66
# 57 iteration is 71.24
# 58 iteration is 68.91
# 59 iteration is 66.65
# 60 iteration is 64.46
# 61 iteration is 62.35
# 62 iteration is 60.31
# 63 iteration is 58.34
# 64 iteration is 56.43
# 65 iteration is 54.59
# 66 iteration is 52.81
# 67 iteration is 51.09
# 68 iteration is 49.43
# 69 iteration is 47.82
# 70 iteration is 46.27
# 71 iteration is 44.77
# 72 iteration is 43.32
# 73 iteration is 41.92
# 74 iteration is 40.56
# 75 iteration is 39.25
# 76 iteration is 37.99
# 77 iteration is 36.76
# 78 iteration is 35.58
# 79 iteration is 34.44
# 80 iteration is 33.33
# 81 iteration is 32.27
# 82 iteration is 31.24
# 83 iteration is 30.24
# 84 iteration is 29.28
# 85 iteration is 28.34
# 86 iteration is 27.44
# 87 iteration is 26.58
# 88 iteration is 25.73
# 89 iteration is 24.92
# 90 iteration is 24.14
# 91 iteration is 23.38
# 92 iteration is 22.64
# 93 iteration is 21.94
# 94 iteration is 21.25
# 95 iteration is 20.59
# 96 iteration is 19.95
# 97 iteration is 19.33
# 98 iteration is 18.73
# 99 iteration is 18.15
# 100 iteration is 17.60
# 101 iteration is 17.06
# 102 iteration is 16.54
# 103 iteration is 16.03
# 104 iteration is 15.54
# 105 iteration is 15.07
# 106 iteration is 14.62
# 107 iteration is 14.18
# 108 iteration is 13.75
# 109 iteration is 13.34
# 110 iteration is 12.95
# 111 iteration is 12.56
# 112 iteration is 12.19
# 113 iteration is 11.83
# 114 iteration is 11.49
# 115 iteration is 11.15
# 116 iteration is 10.83
# 117 iteration is 10.52
# 118 iteration is 10.21
# 119 iteration is 9.92
# 120 iteration is 9.64
# 121 iteration is 9.37
# 122 iteration is 9.10
# 123 iteration is 8.85
# 124 iteration is 8.60
# 125 iteration is 8.36
# 126 iteration is 8.13
# 127 iteration is 7.91
# 128 iteration is 7.70
# 129 iteration is 7.49
# 130 iteration is 7.29
# 131 iteration is 7.09
# 132 iteration is 6.91
# 133 iteration is 6.72
# 134 iteration is 6.55
# 135 iteration is 6.38
# 136 iteration is 6.22
# 137 iteration is 6.06
# 138 iteration is 5.91
# 139 iteration is 5.76
# 140 iteration is 5.62
# 141 iteration is 5.48
# 142 iteration is 5.34
# 143 iteration is 5.21
# 144 iteration is 5.09
# 145 iteration is 4.97
# 146 iteration is 4.85
# 147 iteration is 4.74
# 148 iteration is 4.63
# 149 iteration is 4.53
# 150 iteration is 4.43
# 151 iteration is 4.33
# 152 iteration is 4.23
# 153 iteration is 4.14
# 154 iteration is 4.05
# 155 iteration is 3.97
# 156 iteration is 3.88
# 157 iteration is 3.80
# 158 iteration is 3.73
# 159 iteration is 3.65
# 160 iteration is 3.58
# 161 iteration is 3.51
# 162 iteration is 3.44
# 163 iteration is 3.38
# 164 iteration is 3.32
# 165 iteration is 3.25
# 166 iteration is 3.20
# 167 iteration is 3.14
# 168 iteration is 3.08
# 169 iteration is 3.03
# 170 iteration is 2.98
# 171 iteration is 2.93
# 172 iteration is 2.88
# 173 iteration is 2.84
# 174 iteration is 2.79
# 175 iteration is 2.75
# 176 iteration is 2.71
# 177 iteration is 2.67
# 178 iteration is 2.63
# 179 iteration is 2.59
# 180 iteration is 2.55
# 181 iteration is 2.52
# 182 iteration is 2.48
# 183 iteration is 2.45
# 184 iteration is 2.42
# 185 iteration is 2.39
# 186 iteration is 2.36
# 187 iteration is 2.33
# 188 iteration is 2.30
# 189 iteration is 2.27
# 190 iteration is 2.25
# 191 iteration is 2.22
# 192 iteration is 2.20
# 193 iteration is 2.18
# 194 iteration is 2.15
# 195 iteration is 2.13
# 196 iteration is 2.11
# 197 iteration is 2.09
# 198 iteration is 2.07
# 199 iteration is 2.05
# 200 iteration is 2.03
# 201 iteration is 2.01
# 202 iteration is 2.00
# 203 iteration is 1.98
# 204 iteration is 1.96
# 205 iteration is 1.95
# 206 iteration is 1.93
# 207 iteration is 1.92
# 208 iteration is 1.90
# 209 iteration is 1.89
# 210 iteration is 1.88
# 211 iteration is 1.87
# 212 iteration is 1.85
# 213 iteration is 1.84
# 214 iteration is 1.83
# 215 iteration is 1.82
# 216 iteration is 1.81
# 217 iteration is 1.80
# 218 iteration is 1.79
# 219 iteration is 1.78
# 220 iteration is 1.77
# 221 iteration is 1.76
# 222 iteration is 1.75
# 223 iteration is 1.74
# 224 iteration is 1.73
# 225 iteration is 1.73
# 226 iteration is 1.72
# 227 iteration is 1.71
# 228 iteration is 1.70
# 229 iteration is 1.70
# 230 iteration is 1.69
# 231 iteration is 1.68
# 232 iteration is 1.68
# 233 iteration is 1.67
# 234 iteration is 1.67
# 235 iteration is 1.66
# 236 iteration is 1.66
# 237 iteration is 1.65
# 238 iteration is 1.65
# 239 iteration is 1.64
# 240 iteration is 1.64
# 241 iteration is 1.63
# 242 iteration is 1.63
# 243 iteration is 1.62
# 244 iteration is 1.62
# 245 iteration is 1.61
# 246 iteration is 1.61
# 247 iteration is 1.61
# 248 iteration is 1.60
# 249 iteration is 1.60
# 250 iteration is 1.60
# 251 iteration is 1.59
# 252 iteration is 1.59
# 253 iteration is 1.59
# 254 iteration is 1.58
# 255 iteration is 1.58
# 256 iteration is 1.58
# 257 iteration is 1.58
# 258 iteration is 1.57
# 259 iteration is 1.57
# 260 iteration is 1.57
# 261 iteration is 1.57
# 262 iteration is 1.56
# 263 iteration is 1.56
# 264 iteration is 1.56
# 265 iteration is 1.56
# 266 iteration is 1.56
# 267 iteration is 1.55
# 268 iteration is 1.55
# 269 iteration is 1.55
# 270 iteration is 1.55
# 271 iteration is 1.55
# 272 iteration is 1.55
# 273 iteration is 1.54
# 274 iteration is 1.54
# 275 iteration is 1.54
# 276 iteration is 1.54
# 277 iteration is 1.54
# 278 iteration is 1.54
# 279 iteration is 1.54
# 280 iteration is 1.53
# 281 iteration is 1.53
# 282 iteration is 1.53
# 283 iteration is 1.53
# 284 iteration is 1.53
# 285 iteration is 1.53
# 286 iteration is 1.53
# 287 iteration is 1.53
# 288 iteration is 1.53
# 289 iteration is 1.53
# 290 iteration is 1.52
# 291 iteration is 1.52
# 292 iteration is 1.52
# 293 iteration is 1.52
# 294 iteration is 1.52
# 295 iteration is 1.52
# 296 iteration is 1.52
# 297 iteration is 1.52
# 298 iteration is 1.52
# 299 iteration is 1.52
# 300 iteration is 1.52
# 301 iteration is 1.52
# 302 iteration is 1.52
# 303 iteration is 1.52
# 304 iteration is 1.52
# 305 iteration is 1.51
# 306 iteration is 1.51
# 307 iteration is 1.51
# 308 iteration is 1.51
# 309 iteration is 1.51
# 310 iteration is 1.51
# 311 iteration is 1.51
# 312 iteration is 1.51
# 313 iteration is 1.51
# 314 iteration is 1.51
# 315 iteration is 1.51
# 316 iteration is 1.51
# 317 iteration is 1.51
# 318 iteration is 1.51
# 319 iteration is 1.51
# 320 iteration is 1.51
# 321 iteration is 1.51
# 322 iteration is 1.51
# 323 iteration is 1.51
# 324 iteration is 1.51
# 325 iteration is 1.51
# 326 iteration is 1.51
# 327 iteration is 1.51
# 328 iteration is 1.51
# 329 iteration is 1.51
# 330 iteration is 1.51
# 331 iteration is 1.51
# 332 iteration is 1.51
# 333 iteration is 1.51
# 334 iteration is 1.51
# 335 iteration is 1.51
# 336 iteration is 1.51
# 337 iteration is 1.50
# 338 iteration is 1.50
# 339 iteration is 1.50
# 340 iteration is 1.50
# 341 iteration is 1.50
# 342 iteration is 1.50
# 343 iteration is 1.50
# 344 iteration is 1.50
# 345 iteration is 1.50
# 346 iteration is 1.50
# 347 iteration is 1.50
# 348 iteration is 1.50
# 349 iteration is 1.50
# 350 iteration is 1.50
# 351 iteration is 1.50
# 352 iteration is 1.50
# 353 iteration is 1.50
# 354 iteration is 1.50
# 355 iteration is 1.50
# 356 iteration is 1.50
# 357 iteration is 1.50
# 358 iteration is 1.50
# 359 iteration is 1.50
# 360 iteration is 1.50
# 361 iteration is 1.50
# 362 iteration is 1.50
# 363 iteration is 1.50
# 364 iteration is 1.50
# 365 iteration is 1.50
# 366 iteration is 1.50
# 367 iteration is 1.50
# 368 iteration is 1.50
# 369 iteration is 1.50
# 370 iteration is 1.50
# 371 iteration is 1.50
# 372 iteration is 1.50
# 373 iteration is 1.50
# 374 iteration is 1.50
# 375 iteration is 1.50
# 376 iteration is 1.50
# 377 iteration is 1.50
# 378 iteration is 1.50
# 379 iteration is 1.50
# 380 iteration is 1.50
# 381 iteration is 1.50
# 382 iteration is 1.50
# 383 iteration is 1.50
# 384 iteration is 1.50
# 385 iteration is 1.50
# 386 iteration is 1.50
# 387 iteration is 1.50
# 388 iteration is 1.50
# 389 iteration is 1.50
# 390 iteration is 1.50
# 391 iteration is 1.50
# 392 iteration is 1.50
# 393 iteration is 1.50
# 394 iteration is 1.50
# 395 iteration is 1.50
# 396 iteration is 1.50
# 397 iteration is 1.50
# 398 iteration is 1.50
# 399 iteration is 1.50
# [63.96 70.47 76.99 83.51 90.02]
# w: 6.515647044252297
# b: 57.443509205468956

# %% [markdown]
# # plot for error graph

# %%
import matplotlib.pyplot as plt

plt.plot(loss)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.show()
